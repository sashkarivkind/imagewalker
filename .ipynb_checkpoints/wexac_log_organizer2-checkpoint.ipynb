# %%
import pickle
import re
import numpy as np
import ast

# %%
from os import listdir
import glob

# %%
file_names = glob.glob('../../iclr_result_dirs/teacher_student/out*')

# %%
len(file_names)
# Out:
# 469

# %%
file_name='../../iclr_result_dirs/teacher_student/out_traject.831800'

# %%
def vanilla_out_parser(file_name):    
    count_test_results = 0
    done_config = False
    accu_list=[]
    with open(file_name,'r') as f:
        for line in f:
            if not done_config and line[:6]=='config':
                config_dict_str = line[7:].lstrip()
                done_config = True
            if line[:6] == 'python':
                python_commant = line
            if count_test_results > 0:
                accu = line.split(':')[-1]
                accu_list.append(float(accu))
                count_test_results -= 1
            if 'running 5 times on test data' in line:
                count_test_results = 5

    # print(accu_list)
    if len(accu_list)>0:
        config_dict = ast.literal_eval(config_dict_str)
#         print(config_dict)
#         print(np.mean(accu_list))
        config_dict['accuracy'] = np.mean(accu_list)
        config_dict['accuracy_std'] = np.std(accu_list)
#         config_dict['accuracy'] = np.mean(accu_list)
        return config_dict
    else:
        return None

# %%
records = []
for ii,file_name in enumerate(file_names):
    conf=vanilla_out_parser(file_name)
    if conf is not None:
        conf['file_name']=file_name.split('/')[-1]
        conf['file_name_full']=file_name
        conf['teacher_short']=conf['teacher_net'][-25:]
        print(conf['teacher_short'])
        records.append(conf)
# Out:
# el_196219__1632468206.hdf
# el_196219__1632468206.hdf
# el_196219__1632468206.hdf
# el_196219__1632468206.hdf
# el_846962__1632251071.hdf
# el_846962__1632251071.hdf
# snet/ref_cifar100_02.hdf/
# el_510046__1628691784.hdf
# el_196219__1632468206.hdf
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# el_196219__1632468206.hdf
# snet/ref_cifar100_01.hdf/
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# del_52191__1631198121.hdf
# del_52191__1631198121.hdf
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# el_196219__1632468206.hdf
# esnet/ref_cifar10_03.hdf/
# el_846962__1632251071.hdf
# el_846962__1632251071.hdf
# snet/ref_cifar100_02.hdf/
# del_52191__1631198121.hdf
# el_196219__1632468206.hdf
# del_52191__1631198121.hdf
# el_196219__1632468206.hdf
# el_846962__1632251071.hdf
# del_52191__1631198121.hdf
# el_196219__1632468206.hdf
# el_196219__1632468206.hdf
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# el_846962__1632251071.hdf
# del_52191__1631198121.hdf
# el_846962__1632251071.hdf
# el_846962__1632251071.hdf
# del_52191__1631198121.hdf
# esnet/ref_cifar10_02.hdf/
# del_52191__1631198121.hdf
# esnet/ref_cifar10_02.hdf/
# el_846962__1632251071.hdf
# del_52191__1631198121.hdf
# el_846962__1632251071.hdf
# snet/ref_cifar100_02.hdf/
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# del_52191__1631198121.hdf
# del_52191__1631198121.hdf
# el_196219__1632468206.hdf
# el_196219__1632468206.hdf
# snet/ref_cifar100_03.hdf/
# el_846962__1632251071.hdf
# del_52191__1631198121.hdf
# el_196219__1632468206.hdf
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# esnet/ref_cifar10_03.hdf/
# el_846962__1632251071.hdf
# snet/ref_cifar100_02.hdf/
# el_196219__1632468206.hdf
# el_196219__1632468206.hdf
# el_846962__1632251071.hdf
# del_52191__1631198121.hdf
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# del_52191__1631198121.hdf
# el_196219__1632468206.hdf
# snet/ref_cifar100_03.hdf/
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# el_846962__1632251071.hdf
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# del_52191__1631198121.hdf
# del_52191__1631198121.hdf
# del_52191__1631198121.hdf
# del_52191__1631198121.hdf
# el_846962__1632251071.hdf
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# del_52191__1631198121.hdf
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf
# del_52191__1631198121.hdf
# el_846962__1632251071.hdf
# el_846962__1632251071.hdf
# el_846962__1632251071.hdf
# el_846962__1632251071.hdf
# el_846962__1632251071.hdf
# el_846962__1632251071.hdf
# el_196219__1632468206.hdf

# %%
import pandas as pd

# %%
df = pd.DataFrame(records)

# %%
df.columns
# Out:
# Index(['accuracy', 'accuracy_std', 'batch_norm_student', 'broadcast',
#        'conv_rnn_type', 'data_augmentation', 'dataset_center', 'dataset_norm',
#        'decoder_epochs', 'decoder_optimizer', 'dense_interface', 'dropout',
#        'dropout1', 'dropout2', 'epochs', 'file_name', 'file_name_full',
#        'fine_tune_student', 'height_shift_range', 'int_epochs',
#        'last_layer_size', 'last_maxpool_en', 'layer_norm_2', 'layer_norm_res',
#        'layer_norm_student', 'learning_patience', 'loss', 'manual_suffix',
#        'max_length', 'n_classes', 'n_samples', 'nl', 'noise', 'num_feature',
#        'pretrained_student_path', 'res', 'resblocks', 'resnet_mode',
#        'rnn_dropout', 'rnn_layer1', 'rnn_layer2', 'rotation_range',
#        'run_index', 'run_name_prefix', 'skip_conn', 'skip_student_training',
#        'snellen', 'stopping_patience', 'student_block_size', 'student_nl',
#        'student_version', 'style', 'teacher_net', 'teacher_short', 'testmode',
#        'time_pool', 'time_sec', 'traj_out_scale', 'trajectories_num',
#        'trajectory_index', 'upsample', 'val_set_mult', 'verbose', 'vm_kappa',
#        'width_shift_range'],
#       dtype='object')

# %%
df.sort_values(by=['vm_kappa']).loc[df['style']=='xx1_vonmises_walk'].loc[:,['file_name','style','vm_kappa', 'accuracy']]
# Out:
#              file_name              style  vm_kappa  accuracy
# 20  out_traject.775281  xx1_vonmises_walk      -5.0   0.70802
# 29  out_traject.961905  xx1_vonmises_walk      -5.0   0.70564
# 35  out_traject.744841  xx1_vonmises_walk      -2.0   0.70392
# 1   out_traject.775336  xx1_vonmises_walk      -2.0   0.71188
# 73  out_traject.775394  xx1_vonmises_walk      -1.0   0.70392
# 70  out_traject.775389  xx1_vonmises_walk      -1.0   0.69300
# 64  out_traject.743838  xx1_vonmises_walk       0.0   0.68472
# 94  out_traject.961504  xx1_vonmises_walk       0.0   0.67748
# 8   out_traject.775471  xx1_vonmises_walk       2.0   0.65798
# 63  out_traject.742837  xx1_vonmises_walk       2.0   0.65910
# 10  out_traject.745353  xx1_vonmises_walk       5.0   0.65522
# 3   out_traject.830452  xx1_vonmises_walk       5.0   0.65800
# 52  out_traject.753437  xx1_vonmises_walk      20.0   0.65950
# 86  out_traject.753436  xx1_vonmises_walk      20.0   0.65372

# %%
df.loc[df['style']=='xx1_vonmises_walk']
# Out:
#     accuracy  accuracy_std  batch_norm_student  broadcast conv_rnn_type  \
# 1    0.71188      0.001525               False          1           gru
# 3    0.65800      0.003481               False          1           gru
# 8    0.65798      0.002218               False          1           gru
# 10   0.65522      0.002846               False          1           gru
# 20   0.70802      0.002658               False          1           gru
# 29   0.70564      0.001297               False          1           gru
# 35   0.70392      0.002485               False          1           gru
# 52   0.65950      0.002125               False          1           gru
# 63   0.65910      0.002616               False          1           gru
# 64   0.68472      0.001883               False          1           gru
# 70   0.69300      0.002764               False          1           gru
# 73   0.70392      0.001382               False          1           gru
# 86   0.65372      0.001886               False          1           gru
# 94   0.67748      0.000714               False          1           gru
#
#     data_augmentation  dataset_center  dataset_norm  decoder_epochs  \
# 1                True            True         128.0              40
# 3                True            True         128.0              40
# 8                True            True         128.0              40
# 10               True            True         128.0              40
# 20               True            True         128.0              40
# 29               True            True         128.0              40
# 35               True            True         128.0              40
# 52               True            True         128.0              40
# 63               True            True         128.0              40
# 64               True            True         128.0              40
# 70               True            True         128.0              40
# 73               True            True         128.0              40
# 86               True            True         128.0              40
# 94               True            True         128.0              40
#
#    decoder_optimizer        ...             time_pool  time_sec  \
# 1                SGD        ...          average_pool       0.3
# 3                SGD        ...          average_pool       0.3
# 8                SGD        ...          average_pool       0.3
# 10               SGD        ...          average_pool       0.3
# 20               SGD        ...          average_pool       0.3
# 29               SGD        ...          average_pool       0.3
# 35               SGD        ...          average_pool       0.3
# 52               SGD        ...          average_pool       0.3
# 63               SGD        ...          average_pool       0.3
# 64               SGD        ...          average_pool       0.3
# 70               SGD        ...          average_pool       0.3
# 73               SGD        ...          average_pool       0.3
# 86               SGD        ...          average_pool       0.3
# 94               SGD        ...          average_pool       0.3
#
#     traj_out_scale  trajectories_num  trajectory_index upsample val_set_mult  \
# 1              4.0                -1                 0        7          1.0
# 3              4.0                -1                 0        7          1.0
# 8              4.0                -1                 0        7          1.0
# 10             4.0                -1                 0        7          1.0
# 20             4.0                -1                 0        7          1.0
# 29             4.0                -1                 0        7          1.0
# 35             4.0                -1                 0        7          1.0
# 52             4.0                -1                 0        7          1.0
# 63             4.0                -1                 0        7          1.0
# 64             4.0                -1                 0        7          1.0
# 70             4.0                -1                 0        7          1.0
# 73             4.0                -1                 0        7          1.0
# 86             4.0                -1                 0        7          1.0
# 94             4.0                -1                 0        7          1.0
#
#    verbose  vm_kappa  width_shift_range
# 1        2      -2.0                0.1
# 3        2       5.0                0.1
# 8        2       2.0                0.1
# 10       2       5.0                0.1
# 20       2      -5.0                0.1
# 29       2      -5.0                0.1
# 35       2      -2.0                0.1
# 52       2      20.0                0.1
# 63       2       2.0                0.1
# 64       2       0.0                0.1
# 70       2      -1.0                0.1
# 73       2      -1.0                0.1
# 86       2      20.0                0.1
# 94       2       0.0                0.1
#
# [14 rows x 65 columns]

# %%
df.sort_values(by=['n_classes']).loc[df['style']=='spiral_2dir2'].loc[:,['file_name','teacher_short','style','resnet_mode',
                                                                         'student_block_size',
                                                                         'broadcast','n_samples','n_classes','epochs', 'accuracy']]
# Out:
#              file_name              teacher_short         style  resnet_mode  \
# 40  out_traject.956166  del_52191__1631198121.hdf  spiral_2dir2        False
# 28  out_traject.956103  del_52191__1631198121.hdf  spiral_2dir2        False
# 31  out_traject.956123  del_52191__1631198121.hdf  spiral_2dir2        False
# 25    out_traject.5936  snet/ref_cifar100_02.hdf/  spiral_2dir2         True
# 38  out_traject.831470  el_846962__1632251071.hdf  spiral_2dir2         True
# 41    out_traject.7526  esnet/ref_cifar10_02.hdf/  spiral_2dir2         True
# 43    out_traject.7065  esnet/ref_cifar10_02.hdf/  spiral_2dir2         True
# 48  out_traject.831336  el_846962__1632251071.hdf  spiral_2dir2         True
# 60    out_traject.7527  esnet/ref_cifar10_03.hdf/  spiral_2dir2         True
# 22    out_traject.7057  esnet/ref_cifar10_03.hdf/  spiral_2dir2         True
# 87  out_traject.956187  del_52191__1631198121.hdf  spiral_2dir2        False
# 9   out_traject.831388  el_846962__1632251071.hdf  spiral_2dir2         True
# 89  out_traject.962104  el_846962__1632251071.hdf  spiral_2dir2         True
# 62    out_traject.9256  snet/ref_cifar100_02.hdf/  spiral_2dir2         True
# 59  out_traject.959076  el_196219__1632468206.hdf  spiral_2dir2         True
# 76  out_traject.952479  el_196219__1632468206.hdf  spiral_2dir2         True
# 71    out_traject.9041  snet/ref_cifar100_03.hdf/  spiral_2dir2         True
# 54    out_traject.5865  snet/ref_cifar100_03.hdf/  spiral_2dir2         True
# 6     out_traject.9053  snet/ref_cifar100_02.hdf/  spiral_2dir2         True
# 11  out_traject.764324  el_196219__1632468206.hdf  spiral_2dir2         True
# 12   out_traject.56371  snet/ref_cifar100_01.hdf/  spiral_2dir2         True
# 27  out_traject.831800  el_196219__1632468206.hdf  spiral_2dir2         True
# 33  out_traject.962103  el_196219__1632468206.hdf  spiral_2dir2         True
# 47    out_traject.5728  snet/ref_cifar100_02.hdf/  spiral_2dir2         True
#
#     student_block_size  broadcast  n_samples  n_classes  epochs  accuracy
# 40                   2          0         10       10.0     100   0.84638
# 28                   2          1          5       10.0     100   0.84594
# 31                   2          1         10       10.0     100   0.86538
# 25                   1          0          5       10.0     100   0.86200
# 38                   1          1         10       10.0     100   0.94866
# 41                   1          1          5       10.0     100   0.92444
# 43                   1          0          5       10.0     100   0.87450
# 48                   1          1          5       10.0     100   0.92068
# 60                   1          1          5       10.0     100   0.92266
# 22                   1          0          5       10.0     100   0.88212
# 87                   1          0         10       10.0     100   0.83422
# 9                    2          1          5       10.0     100   0.93342
# 89                   1          0          5       10.0     100   0.87826
# 62                   1          1         10      100.0     100   0.78004
# 59                   1          1         10      100.0     100   0.79208
# 76                   1          1         10      100.0      50   0.78470
# 71                   1          1          5      100.0     100   0.74112
# 54                   1          0          5      100.0     100   0.66904
# 6                    1          1          5      100.0     100   0.74330
# 11                   1          1          5      100.0     100   0.74252
# 12                   1          0          5      100.0     100   0.67496
# 27                   2          1          5      100.0     100   0.76284
# 33                   2          0          5      100.0     100   0.71394
# 47                   1          0          5      100.0     100   0.67292

# %%
df.sort_values(by=['n_classes']).loc[df['style']=='spiral_2dir2'].loc[df['resnet_mode']].loc[:,['file_name','teacher_short','style','resnet_mode',
                                                                         'student_block_size',
                                                                         'broadcast','n_samples','n_classes','epochs', 'accuracy']]
# Out:
#              file_name              teacher_short         style  resnet_mode  \
# 25    out_traject.5936  snet/ref_cifar100_02.hdf/  spiral_2dir2         True
# 38  out_traject.831470  el_846962__1632251071.hdf  spiral_2dir2         True
# 41    out_traject.7526  esnet/ref_cifar10_02.hdf/  spiral_2dir2         True
# 43    out_traject.7065  esnet/ref_cifar10_02.hdf/  spiral_2dir2         True
# 48  out_traject.831336  el_846962__1632251071.hdf  spiral_2dir2         True
# 60    out_traject.7527  esnet/ref_cifar10_03.hdf/  spiral_2dir2         True
# 22    out_traject.7057  esnet/ref_cifar10_03.hdf/  spiral_2dir2         True
# 9   out_traject.831388  el_846962__1632251071.hdf  spiral_2dir2         True
# 89  out_traject.962104  el_846962__1632251071.hdf  spiral_2dir2         True
# 62    out_traject.9256  snet/ref_cifar100_02.hdf/  spiral_2dir2         True
# 59  out_traject.959076  el_196219__1632468206.hdf  spiral_2dir2         True
# 76  out_traject.952479  el_196219__1632468206.hdf  spiral_2dir2         True
# 71    out_traject.9041  snet/ref_cifar100_03.hdf/  spiral_2dir2         True
# 54    out_traject.5865  snet/ref_cifar100_03.hdf/  spiral_2dir2         True
# 6     out_traject.9053  snet/ref_cifar100_02.hdf/  spiral_2dir2         True
# 11  out_traject.764324  el_196219__1632468206.hdf  spiral_2dir2         True
# 12   out_traject.56371  snet/ref_cifar100_01.hdf/  spiral_2dir2         True
# 27  out_traject.831800  el_196219__1632468206.hdf  spiral_2dir2         True
# 33  out_traject.962103  el_196219__1632468206.hdf  spiral_2dir2         True
# 47    out_traject.5728  snet/ref_cifar100_02.hdf/  spiral_2dir2         True
#
#     student_block_size  broadcast  n_samples  n_classes  epochs  accuracy
# 25                   1          0          5       10.0     100   0.86200
# 38                   1          1         10       10.0     100   0.94866
# 41                   1          1          5       10.0     100   0.92444
# 43                   1          0          5       10.0     100   0.87450
# 48                   1          1          5       10.0     100   0.92068
# 60                   1          1          5       10.0     100   0.92266
# 22                   1          0          5       10.0     100   0.88212
# 9                    2          1          5       10.0     100   0.93342
# 89                   1          0          5       10.0     100   0.87826
# 62                   1          1         10      100.0     100   0.78004
# 59                   1          1         10      100.0     100   0.79208
# 76                   1          1         10      100.0      50   0.78470
# 71                   1          1          5      100.0     100   0.74112
# 54                   1          0          5      100.0     100   0.66904
# 6                    1          1          5      100.0     100   0.74330
# 11                   1          1          5      100.0     100   0.74252
# 12                   1          0          5      100.0     100   0.67496
# 27                   2          1          5      100.0     100   0.76284
# 33                   2          0          5      100.0     100   0.71394
# 47                   1          0          5      100.0     100   0.67292

# %%
df.to_pickle('DRC_results_Oct3_21.pkl')

# %%
700*100/3600
# Out:
# 19.444444444444443

# %%
conf['file_name_full']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-237-222fb93f2757> in <module>
# ----> 1 conf['file_name_full']
#
# TypeError: 'NoneType' object is not subscriptable
