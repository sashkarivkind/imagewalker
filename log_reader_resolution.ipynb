# %%
import pickle
import re
from misc import HP
import numpy as np
# run_dir = 'saved_runs/run_saccader101.py_noname_1599661925_6632/'
# run_dir = 'saved_runs/run_saccader101.py_noname_1599754363_29285/' #first mnist drift nwk
# run_dir = 'saved_runs/run_saccader101.py_noname_1600242042_31433/' #2nd try
# 
run_dir = 'saved_runs/run_saccader101.py_noname_1600298762_40996/' #no drift input to saccade nwk
# run_dir = 'saved_runs/run_syclop_generic_cnn_vfb_neu.py_noname_1593433483_72434/'
# run_dir = 'saved_runs/run_syclop_generic1.py_noname_1576147784_0/'

with open(run_dir+'hp.pkl','rb') as f:
    hp=pickle.load(f)

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

# %%
hp.description
# Out:
# 'drift network pre-trained on mnist patches, try3-No signal to saccadic net from drift net'

# %%
num_template="[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?"

frame_list=[]
reward_list=[]
with open(run_dir+'log.log','r') as f:
    for line in f:
        if 'frame' in line:
            frame_list.append(float(re.findall(num_template,line)[0]))
        if 'running reward' in line:
            reward_list.append(float(re.findall(num_template,line)[-1]))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(reward_list,'.')
plt.plot(smooth(reward_list,30)[:-30],'r.')
plt.xlabel('epoch')
plt.ylabel('reward')
# Out:
# Text(0, 0.5, 'reward')

# %%
plt.plot(reward_list,'.')
plt.plot(smooth(reward_list,30)[:-30],'r.')
plt.xlabel('epoch')
plt.ylabel('reward')
# Out:
# Text(0, 0.5, 'reward')

# %%
plt.plot(reward_list,'.')
plt.plot(smooth(reward_list,30)[:-30],'r.')
plt.xlabel('epoch')
plt.ylabel('reward')
# Out:
# Text(0, 0.5, 'reward')

# %%
plt.plot(reward_list,'.')
plt.plot(smooth(reward_list,30),'r.')

# %%
def read_reward_from_logs(run_dir,pos=-1):
    num_template="[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?"

    frame_list=[]
    reward_list=[]
    with open(run_dir+'log.log','r') as f:
        for line in f:
            if 'frame' in line:
                frame_list.append(float(re.findall(num_template,line)[0]))
            if 'running reward' in line:
                reward_list.append(float(re.findall(num_template,line)[pos]))
    return reward_list

# %%
def read_accuracy_from_logs(run_dir,pos=-1):
    num_template="[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?"

    frame_list=[]
    reward_list=[]
    with open(run_dir+'log.log','r') as f:
        for line in f:
            if 'frame' in line:
                frame_list.append(float(re.findall(num_template,line)[0]))
            if 'accuracy' in line:
                reward_list.append(float(re.findall(num_template,line)[pos]))
    return reward_list #run_syclop_resolution214.py

# %%
run_dirs = ['saved_runs/trajectory_curriculum101.py_noname__835743_1623527592_1/', #first mnist drift nwk
        'saved_runs/trajectory_curriculum101.py_noname__665055_1622974198_1/', #2nd try
        'saved_runs/trajectory_curriculum101.py_noname__667690_1622980067_1/', #2nd try
        'saved_runs/trajectory_curriculum101.py_noname__721855_1623070706_1/']
plt.figure()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir)
    plt.plot(smooth(reward_list[:-1],1),'.')
plt.legend(['single traj','multi traj','curriculum','multi-traj-multy-layer'])

# %%
run_dirs = ['saved_runs/run_syclop_resolution214.py_noname__815263_1623341276_1/',
           'saved_runs/run_syclop_resolution214.py_noname__815272_1623342830_1/']
plt.figure()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir)
    plt.plot(smooth(reward_list[:-1],1),'.')
plt.legend(['accuracy+intensity','only accuracy'])

# %%
run_dirs = ['saved_runs/trajectory_curriculum101.py_noname__835743_1623527592_1/', #first mnist drift nwk
        'saved_runs/trajectory_curriculum101.py_noname__665055_1622974198_1/', #2nd try
        'saved_runs/trajectory_curriculum101.py_noname__667690_1622980067_1/', #2nd try
        'saved_runs/trajectory_curriculum101.py_noname__721850_1623070675_1//', #2nd tr            
        'saved_runs/trajectory_curriculum101.py_noname__721855_1623070706_1/']
plt.figure()
plt.grid()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir)
    plt.plot(smooth(reward_list[:-1],1),'.')
# plt.legend(['single traj','multi traj','curriculum','multi-traj-multy-layer'])

# %%
reward_list[:-1]
# Out:
# [0.4672,
#  0.5356,
#  0.5654,
#  0.6006,
#  0.6148,
#  0.6146,
#  0.6266,
#  0.6492,
#  0.6588,
#  0.6694,
#  0.6814,
#  0.6904,
#  0.6856,
#  0.7118,
#  0.7066,
#  0.7056,
#  0.7196,
#  0.6946,
#  0.7272,
#  0.7326,
#  0.7184,
#  0.7304,
#  0.742,
#  0.7294,
#  0.7438,
#  0.7424,
#  0.7404,
#  0.7308,
#  0.7572,
#  0.7482,
#  0.755,
#  0.753,
#  0.7512,
#  0.7604,
#  0.7786,
#  0.7722,
#  0.7694,
#  0.7646,
#  0.768,
#  0.7776,
#  0.7588,
#  0.7742,
#  0.7886,
#  0.773,
#  0.7714,
#  0.7766,
#  0.7786,
#  0.7856,
#  0.7704,
#  0.786,
#  0.7864,
#  0.7908,
#  0.7788,
#  0.7876,
#  0.7922,
#  0.7984,
#  0.7934,
#  0.7886,
#  0.7922,
#  0.7964,
#  0.7938,
#  0.8056,
#  0.8034,
#  0.7918,
#  0.8002,
#  0.8074,
#  0.798,
#  0.7874,
#  0.799,
#  0.7934,
#  0.788,
#  0.795,
#  0.8082,
#  0.8006,
#  0.8114,
#  0.811,
#  0.8116,
#  0.8114,
#  0.8042,
#  0.8124,
#  0.7996,
#  0.8072,
#  0.807,
#  0.7902,
#  0.803,
#  0.802,
#  0.8086,
#  0.816,
#  0.8136,
#  0.814,
#  0.8196,
#  0.82,
# ...

# %%
run_dirs = [           
        'saved_runs/trajectory_curriculum101.py_noname__721855_1623070706_1/']
plt.figure()
plt.grid()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir)
    plt.plot(smooth(reward_list[:-1],1),'.')
    reward_list2=read_accuracy_from_logs(run_dir,pos=-3)
    plt.plot(smooth(reward_list2[:-1],1),'.')
# plt.legend(['single traj','multi traj','curriculum','multi-traj-multy-layer'])

# %%
example1: 
bsub -q gpu-short -app nvidia-gpu -env LSB_CONTAINER_IMAGE=ibdgx001:5000/tensorflow1_cv:v4-base-19.12-tf1-py3-cv4p0 -gpu num=2:j_exclusive=yes -R "affinity[thread*32] select[mem>10192]" -R "select[hname!=agn03] rusage[mem=10192]" -o out_timing0.%J -e err_timing0.%J python run_syclop_resolution214.py --resolution 6 --max_episode 1000000 --steps_per_episode 5 --train_decoder_every 200 --intensity_reward 0.1 --speed_reward 0.0 --loss_reward 100.0  --decoder_initial_network saved_runs/trajectory_curriculum101.py_noname__800360_1623317359_1/final_decoder.nwk --decoder_learning_rate 0.001  --decoder_ignore_position  --no-decode_from_central --no-decoder_train_en  --decoder_prescale 0.004
example2:
bsub -q gpu-short -app nvidia-gpu -env LSB_CONTAINER_IMAGE=ibdgx001:5000/tensorflow1_cv:v4-base-19.12-tf1-py3-cv4p0 -gpu num=2:j_exclusive=yes -R "affinity[thread*32] select[mem>8192] rusage[mem=8192]" -o out_curr.%J -e err_curr.%J python trajectory_curriculum101.py  --resolution 6 --num_epochs 200 --alpha_increment 0.0000001 --fit_verbose 2   --conv_fe --decoder_rnn_layers 5  --decoder_learning_rate 0.001

# %%
# [arivkind@access3 rlnet_102]$ less out*252901
# [arivkind@access3 rlnet_102]$ less out*256959
# [arivkind@access3 rlnet_102]$ less out*256732
# [arivkind@access3 rlnet_102]$ less out*252901
run_dirs = ['saved_runs/run_syclop_resolution214.py_noname__815263_1623341276_1/',
           'saved_runs/run_syclop_resolution214.py_noname__815272_1623342830_1/',
           'saved_runs/run_syclop_resolution214.py_noname__252901_1624138489_1/',
           'saved_runs/run_syclop_resolution214.py_noname__256959_1624146914_1/',
           'saved_runs/run_syclop_resolution214.py_noname__256732_1624140550_1/',
           'saved_runs/run_syclop_resolution214.py_noname__252721_1624138181_1/',
           
           ]
plt.figure()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir)
    plt.plot(smooth(reward_list[:-1],1),'.')
plt.legend(['accuracy+intensity','only accuracy'])
plt.grid()

# %%
run_dirs = ['saved_runs/run_syclop_resolution214.py_noname__252901_1624138489_1/',
#            'saved_runs/run_syclop_resolution214.py_noname__256959_1624146914_1/',
           'saved_runs/run_syclop_resolution214.py_noname__256732_1624140550_1/',
           'saved_runs/run_syclop_resolution214.py_noname__252721_1624138181_1/',
           
           ]
plt.figure()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir)
    plt.plot(smooth(reward_list[1:-1],1),'.')
plt.legend(['accuracy+intensity','only accuracy'])
plt.grid()

# %%
run_dirs = ['saved_runs/run_syclop_resolution214.py_noname__252901_1624138489_1/',
#            'saved_runs/run_syclop_resolution214.py_noname__256959_1624146914_1/',
           'saved_runs/run_syclop_resolution214.py_noname__256732_1624140550_1/',
           'saved_runs/run_syclop_resolution214.py_noname__252721_1624138181_1/',
           
           ]
plt.figure()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir)
    plt.plot(smooth(reward_list[1:-1],1),'.')
plt.legend(['slower target upd, 0.1,100','slower target upd, 0.0,100', 'slower tgt, slower learning'])
plt.grid()

# %%
run_dirs = ['saved_runs/trajectory_curriculum101.py_noname__721855_1623070706_1/',
            'saved_runs/trajectory_curriculum101.py_noname__200012_1624129553_1/', #first mnist drift nwk
        'saved_runs/trajectory_curriculum101.py_noname__687048_1624023326_1/']
plt.figure()
plt.grid()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir)
    plt.plot(smooth(reward_list[:-1],5),'.')
plt.legend(['baseline','longer traj','multi-core..'])

# %%
run_dirs = ['saved_runs/trajectory_curriculum101.py_noname__721855_1623070706_1/',
            'saved_runs/trajectory_curriculum101.py_noname__200012_1624129553_1/', #first mnist drift nwk
        'saved_runs/trajectory_curriculum101.py_noname__687048_1624023326_1/']
plt.figure()
plt.grid()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir,pos=-3)
    plt.plot(smooth(reward_list[:-1],5),'.')
plt.legend(['baseline','longer traj','multi-core..'])

# %%
run_dirs = ['saved_runs/trajectory_curriculum101.py_noname__687048_1624023326_1/']
plt.figure()
plt.grid()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir,pos=-3)
    plt.plot(smooth(reward_list[:-1],5),'.')
    reward_list=read_accuracy_from_logs(run_dir,pos=-1)
    plt.plot(smooth(reward_list[:-1],5),'.')
plt.legend(['test','train'])

run_dirs = ['saved_runs/trajectory_curriculum101.py_noname__687048_1624023326_1/']
plt.figure()
plt.grid()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir,pos=-3)
    plt.plot(smooth(reward_list[:-1],5),'.')
    reward_list=read_accuracy_from_logs(run_dir,pos=-1)
    plt.plot(smooth(reward_list[:-1],5),'.')
plt.legend(['test','train'])

# %%
run_dirs = ['saved_runs/trajectory_curriculum101.py_noname__721855_1623070706_1/',
            'saved_runs/trajectory_curriculum101.py_noname__200012_1624129553_1/',
        'saved_runs/trajectory_curriculum101.py_noname__687048_1624023326_1/']

for run_dir in run_dirs:
    plt.figure()
    plt.grid()
    reward_list=read_accuracy_from_logs(run_dir,pos=-3)
    plt.plot(smooth(reward_list[:-1],5),'.')
    reward_list=read_accuracy_from_logs(run_dir,pos=-1)
    plt.plot(smooth(reward_list[:-1],5),'.')

# %%
run_dirs = ['saved_runs/trajectory_curriculum101.py_noname__721855_1623070706_1/',
            'saved_runs/trajectory_curriculum101.py_noname__200012_1624129553_1/', #first mnist drift nwk
        'saved_runs/trajectory_curriculum101.py_noname__687048_1624023326_1/']
plt.figure()
plt.grid()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir)
    plt.plot(smooth(reward_list[:-1],5),'.')
plt.legend(['baseline','longer traj','multi-core..'])
plt.ylim([0.75,0.9])
# Out:
# (0.75, 0.9)

# %%
run_dirs = [
           'saved_runs/run_syclop_resolution214.py_noname__389054_1624446364_1/',
           'saved_runs/run_syclop_resolution214.py_noname__389069_1624446364_1/',
           'saved_runs/run_syclop_resolution214.py_noname__375372_1624442233_1/',
           'saved_runs/run_syclop_resolution214.py_noname__389082_1624454061_1//',
           'saved_runs/run_syclop_resolution214.py_noname__395309_1624454061_1/',
           'saved_runs/run_syclop_resolution214.py_noname__477049_1624485721_1/',
    
           
           ]
plt.figure()
for run_dir in run_dirs:
    reward_list=read_accuracy_from_logs(run_dir)
    plt.plot(smooth(reward_list[1:-1],5),'.')
plt.legend([''])
plt.ylim([0.8,0.9])
plt.grid()

# %%
np.log(9)
# Out:
# 2.1972245773362196
