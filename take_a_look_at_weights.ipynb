# %%
import pickle
import numpy as np
with open('nwk200x200xrelu_0p1.nwk', 'rb') as f:
    theta= pickle.load(f)

# %%
theta[1]
# Out:
# {'b': array([[-0.07349951,  0.12967137,  0.2604655 ]], dtype=float32),
#  'w': array([[ 0.08642718, -0.15933609,  0.32530937],
#         [-0.65506506,  0.6007865 ,  0.590034  ],
#         [-0.21871483,  0.25417456, -0.3055161 ],
#         [-0.23046038,  0.26459977, -0.46136463],
#         [ 0.3336803 , -0.3028894 , -0.23853815],
#         [ 0.2401792 , -0.1993716 , -0.45572105],
#         [ 0.28986102, -0.32125616,  0.356724  ],
#         [ 0.43985087, -0.4308376 , -0.77441573],
#         [ 0.21958368, -0.44347468,  0.48366204],
#         [ 0.10290092, -0.05162215, -0.5182515 ],
#         [-0.09468051,  0.14952354, -0.4204049 ],
#         [-0.14935376,  0.20632441, -0.53943235],
#         [-0.44094285,  0.48135144, -0.19975267],
#         [ 0.1565158 , -0.14556588,  0.04717482],
#         [-0.14148597,  0.1610402 , -0.01016021],
#         [ 0.727071  , -0.7718056 ,  0.18410909],
#         [-0.44693667,  0.3950628 ,  0.46994382],
#         [-0.21657102,  0.2349271 ,  0.07421805],
# ...

# %%
for l in theta:
    for wb in theta[l]:
        print(l,wb, np.min(theta[l][wb]),np.max(theta[l][wb]))
# Out:
# 0 b -1.9772816 1.1834438
# 0 w -4.9996953 2.4867947
# 1 b -0.6688777 0.9187486
# 1 w -3.218534 2.5704086
# 2 b -0.07349951 0.2604655
# 2 w -2.482381 2.4400902
