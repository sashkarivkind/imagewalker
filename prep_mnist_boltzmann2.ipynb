# %%
import pickle
from misc import *
import SYCLOP_env as syc
from RL_brain_b import DeepQNetwork

# %%
import cv2
import time

# %%
from mnist import MNIST

mnist = MNIST('/home/bnapp/datasets/mnist/')
images, labels = mnist.load_training()
some_mnistSM =[ cv2.resize(1.+np.reshape(uu,[28,28]), dsize=(256, 256)) for uu in images[:2]]#[:4096]]

# %%
run_dir ='saved_runs/run_syclop_generic1.py_noname_1567934052/'

# %%
hp = HP()
hp.mem_depth=1
hp.logmode=False
batch_size=256
action_space_size=9
# images = some_mnistSM
number_of_images = len(images)
reward = syc.Rewards()
observation_size = 256*4
RL = DeepQNetwork(action_space_size, observation_size*hp.mem_depth,#sensor.frame_size+2,
                  reward_decay=0.99,
                  e_greedy=1-1e-9,
                  e_greedy0=1-1e-9,
                  replace_target_iter=10,
                  memory_size=100000,
                  e_greedy_increment=0.0001,
                  learning_rate=0.0025,
                  double_q=False,
                  dqn_mode=True,
                  state_table=np.zeros([1,observation_size*hp.mem_depth]),
                  soft_q_type='boltzmann',
                  beta=0.1
                  )

# %%
def local_observer(sensor,agent):
    if hp.logmode:
        normfactor=1.0
    else:
        normfactor = 1.0/256.0
    return normfactor*np.concatenate([relu_up_and_down(sensor.central_dvs_view),
            relu_up_and_down(cv2.resize(1.0*sensor.dvs_view, dsize=(16, 16), interpolation=cv2.INTER_AREA))])

observation = np.random.uniform(0,1,size=[hp.mem_depth, observation_size])

# %%
scene_bb = [None]*batch_size
sensor_bb =[None]*batch_size
agent_bb = [None]*batch_size
action_bb = [None]*batch_size
action_list_bb =  [None]*batch_size
q_list_bb =  [None]*batch_size
observation_bb = [None]*batch_size
for bb in range(batch_size):
    scene_bb[bb] = syc.Scene(frame_list=some_mnistSM[0:1])
    sensor_bb[bb] = syc.Sensor()
    agent_bb[bb] = syc.Agent(max_q = [scene_bb[bb].maxx-sensor_bb[bb].hp.winx,scene_bb[bb].maxy-sensor_bb[bb].hp.winy])

# %%
result_type = 'best_liron.nwk'
RL.dqn.load_nwk_param(run_dir+'/'+ result_type) #tempX_1.nwk')
with open(run_dir+'/hp.pkl','rb') as f:
          this_hp = pickle.load(f)
          hp.fading_mem = this_hp.fading_mem +0.0 #to avoid assignment by address
            
action_records=[]
q_records=[]
observation_feeder=np.zeros([batch_size,1024])
for image_num,image in enumerate(images):
    step = 0
    episode = 0
for batch_num in range(len(images)//batch_size):
    for bb in range(batch_size):
        action_list_bb[bb] = []
#         q_list_bb[bb] = []
        observation_bb[bb] = np.random.uniform(0,1,size=[hp.mem_depth, observation_size])
        observation_bb[bb] = np.random.uniform(0,1,size=[hp.mem_depth, observation_size])
#         scene_bb[bb].current_frame = image_num[bb]
        scene_bb[bb].image = cv2.resize(1.+np.reshape(images[batch_num*batch_size+bb],[28,28]), dsize=(256, 256))

        agent_bb[bb].reset()
        agent_bb[bb].q_ana[1]=256./2.-32
        agent_bb[bb].q_ana[0]=256./2-32
        agent_bb[bb].q = np.int32(np.floor(agent_bb[bb].q_ana))

        sensor_bb[bb].reset()
        sensor_bb[bb].update(scene_bb[bb], agent_bb[bb])
        sensor_bb[bb].update(scene_bb[bb], agent_bb[bb])
        
    time1=time.time()
    for step_prime in range(1000):
        deep_time1=time.time()
#         action = RL.choose_action(observation.reshape([-1]))
        for bb in range(batch_size):
            observation_feeder[bb,:]=observation_bb[bb].reshape([1,-1])
        oo = RL.dqn.eval(observation_feeder)        
        boltzmann_measure = np.exp(RL.beta * (oo-np.max(oo,axis=1).reshape([-1,1]))) #todo here substracted max to avoid exponent exploding. need to be taken into a separate function!
        boltzmann_measure = boltzmann_measure / np.sum(boltzmann_measure, axis=1).reshape([-1,1])
        for bb in range(batch_size):
            action_bb[bb] = np.random.choice(list(range(RL.n_actions)),1, p=boltzmann_measure[bb,:].reshape([-1]))[0]
        
#         action_bb= [a for a in np.argmax(oo,axis=1)]
        deep_time2=time.time()
        shallow_time1=time.time()
        
        for bb in range(batch_size):
            agent_bb[bb].act(action_bb[bb])
            action_list_bb[bb].append(action_bb[bb])
#             q_list_bb[bb].append(agent_bb[bb].q_ana)
            sensor_bb[bb].update(scene_bb[bb],agent_bb[bb])
            observation_bb[bb] *= hp.fading_mem
            observation_bb[bb] += local_observer(sensor_bb[bb], agent_bb[bb])  # todo: generalize
        shallow_time2=time.time()
#         print('deep:',deep_time2-deep_time1,'shallow:',shallow_time2-shallow_time1)
    time2=time.time()
    
    print('batch num:',batch_num,'wall time consumed:',time2-time1)
    for bb in range(batch_size):
        action_records.append(action_list_bb[bb])
#         q_records.append(q_list_bb[bb])
# Out:
# batch num: 0 wall time consumed: 40.44301652908325
# batch num: 1 wall time consumed: 40.39213752746582
# batch num: 2 wall time consumed: 40.64440870285034
# batch num: 3 wall time consumed: 40.323012590408325
# batch num: 4 wall time consumed: 40.58241534233093
# batch num: 5 wall time consumed: 40.53198719024658
# batch num: 6 wall time consumed: 40.09640574455261
# batch num: 7 wall time consumed: 41.42053580284119
# batch num: 8 wall time consumed: 40.54524040222168
# batch num: 9 wall time consumed: 40.398210287094116
# batch num: 10 wall time consumed: 40.15473175048828
# batch num: 11 wall time consumed: 40.4269700050354
# batch num: 12 wall time consumed: 40.26547837257385
# batch num: 13 wall time consumed: 40.28032565116882
# batch num: 14 wall time consumed: 40.13082671165466
# batch num: 15 wall time consumed: 40.1972713470459
# batch num: 16 wall time consumed: 40.76809525489807
# batch num: 17 wall time consumed: 40.2131769657135
# batch num: 18 wall time consumed: 40.48039364814758
# batch num: 19 wall time consumed: 40.52693819999695
# batch num: 20 wall time consumed: 40.291581869125366
# batch num: 21 wall time consumed: 40.40788745880127
# batch num: 22 wall time consumed: 40.37724304199219
# batch num: 23 wall time consumed: 40.50869679450989
# batch num: 24 wall time consumed: 40.57154130935669
# batch num: 25 wall time consumed: 40.442161560058594
# batch num: 26 wall time consumed: 40.41738271713257
# batch num: 27 wall time consumed: 39.96294951438904
# batch num: 28 wall time consumed: 40.193167209625244
# batch num: 29 wall time consumed: 40.3582067489624
# batch num: 30 wall time consumed: 40.36103820800781
# batch num: 31 wall time consumed: 40.53566789627075
# batch num: 32 wall time consumed: 40.638001918792725
# batch num: 33 wall time consumed: 40.316455364227295
# batch num: 34 wall time consumed: 40.03741097450256
# batch num: 35 wall time consumed: 40.160547971725464
# batch num: 36 wall time consumed: 40.072585344314575
# batch num: 37 wall time consumed: 40.36126494407654
# batch num: 38 wall time consumed: 40.153486490249634
# batch num: 39 wall time consumed: 40.72209620475769
# batch num: 40 wall time consumed: 40.253055810928345
# batch num: 41 wall time consumed: 40.05532383918762
# batch num: 42 wall time consumed: 40.4066526889801
# batch num: 43 wall time consumed: 40.48293852806091
# batch num: 44 wall time consumed: 40.22718906402588
# batch num: 45 wall time consumed: 40.51172733306885
# batch num: 46 wall time consumed: 40.31401014328003
# batch num: 47 wall time consumed: 39.982346057891846
# batch num: 48 wall time consumed: 40.55336022377014
# batch num: 49 wall time consumed: 40.023499965667725
# batch num: 50 wall time consumed: 40.14447641372681
# batch num: 51 wall time consumed: 40.457645416259766
# batch num: 52 wall time consumed: 40.048919677734375
# batch num: 53 wall time consumed: 40.40457844734192
# batch num: 54 wall time consumed: 40.28576326370239
# batch num: 55 wall time consumed: 40.515077352523804
# batch num: 56 wall time consumed: 40.34971499443054
# batch num: 57 wall time consumed: 40.365949869155884
# batch num: 58 wall time consumed: 40.28146481513977
# batch num: 59 wall time consumed: 40.73591661453247
# batch num: 60 wall time consumed: 40.38970422744751
# batch num: 61 wall time consumed: 40.565768003463745
# batch num: 62 wall time consumed: 40.34937119483948
# batch num: 63 wall time consumed: 40.56766629219055
# batch num: 64 wall time consumed: 41.03147888183594
# batch num: 65 wall time consumed: 40.34361720085144
# batch num: 66 wall time consumed: 40.38064193725586
# batch num: 67 wall time consumed: 40.3667573928833
# batch num: 68 wall time consumed: 40.52829098701477
# batch num: 69 wall time consumed: 40.41313815116882
# batch num: 70 wall time consumed: 40.57183647155762
# batch num: 71 wall time consumed: 40.41948938369751
# batch num: 72 wall time consumed: 40.4154155254364
# batch num: 73 wall time consumed: 40.62408089637756
# batch num: 74 wall time consumed: 40.49851179122925
# batch num: 75 wall time consumed: 40.51982831954956
# batch num: 76 wall time consumed: 40.31794619560242
# batch num: 77 wall time consumed: 40.468281507492065
# batch num: 78 wall time consumed: 40.484679222106934
# batch num: 79 wall time consumed: 40.26625633239746
# batch num: 80 wall time consumed: 40.41580033302307
# batch num: 81 wall time consumed: 40.685808181762695
# batch num: 82 wall time consumed: 40.492329359054565
# batch num: 83 wall time consumed: 40.461491107940674
# batch num: 84 wall time consumed: 40.326894998550415
# batch num: 85 wall time consumed: 40.44910979270935
# batch num: 86 wall time consumed: 40.68485951423645
# batch num: 87 wall time consumed: 40.372868061065674
# batch num: 88 wall time consumed: 40.545403480529785
# batch num: 89 wall time consumed: 40.444902181625366
# batch num: 90 wall time consumed: 40.263721227645874
# batch num: 91 wall time consumed: 40.64678144454956
# batch num: 92 wall time consumed: 40.61030197143555
# batch num: 93 wall time consumed: 40.229761362075806
# batch num: 94 wall time consumed: 40.06825566291809
# batch num: 95 wall time consumed: 40.36381793022156
# batch num: 96 wall time consumed: 40.54880452156067
# batch num: 97 wall time consumed: 40.37953805923462
# batch num: 98 wall time consumed: 40.358500480651855
# batch num: 99 wall time consumed: 40.65941786766052
# batch num: 100 wall time consumed: 40.38253712654114
# batch num: 101 wall time consumed: 40.56864929199219
# batch num: 102 wall time consumed: 39.88174486160278
# batch num: 103 wall time consumed: 40.68954014778137
# batch num: 104 wall time consumed: 40.34966206550598
# batch num: 105 wall time consumed: 40.40081858634949
# batch num: 106 wall time consumed: 40.24222540855408
# batch num: 107 wall time consumed: 40.557575702667236
# batch num: 108 wall time consumed: 40.56663203239441
# batch num: 109 wall time consumed: 40.373820304870605
# batch num: 110 wall time consumed: 40.27684020996094
# batch num: 111 wall time consumed: 40.28574204444885
# batch num: 112 wall time consumed: 40.37806749343872
# batch num: 113 wall time consumed: 40.1011426448822
# batch num: 114 wall time consumed: 40.41853046417236
# batch num: 115 wall time consumed: 40.39435815811157
# batch num: 116 wall time consumed: 40.23035550117493
# batch num: 117 wall time consumed: 40.53682255744934
# batch num: 118 wall time consumed: 40.356661319732666
# batch num: 119 wall time consumed: 40.28282976150513
# batch num: 120 wall time consumed: 40.37703013420105
# batch num: 121 wall time consumed: 39.910510301589966
# batch num: 122 wall time consumed: 40.78227138519287
# batch num: 123 wall time consumed: 40.51239347457886
# batch num: 124 wall time consumed: 40.21731185913086
# batch num: 125 wall time consumed: 40.0879807472229
# batch num: 126 wall time consumed: 40.37357783317566
# batch num: 127 wall time consumed: 40.31440043449402
# batch num: 128 wall time consumed: 40.202516317367554
# batch num: 129 wall time consumed: 40.439375162124634
# batch num: 130 wall time consumed: 40.426366329193115
# batch num: 131 wall time consumed: 40.77296257019043
# batch num: 132 wall time consumed: 40.39751124382019
# batch num: 133 wall time consumed: 40.24037790298462
# batch num: 134 wall time consumed: 40.096038579940796
# batch num: 135 wall time consumed: 40.14025640487671
# batch num: 136 wall time consumed: 40.411831855773926
# batch num: 137 wall time consumed: 40.20615029335022
# batch num: 138 wall time consumed: 40.07511806488037
# batch num: 139 wall time consumed: 40.40887928009033
# batch num: 140 wall time consumed: 40.319844245910645
# batch num: 141 wall time consumed: 40.478076219558716
# batch num: 142 wall time consumed: 40.420570373535156
# batch num: 143 wall time consumed: 40.50088047981262
# batch num: 144 wall time consumed: 40.374330282211304
# batch num: 145 wall time consumed: 40.32880902290344
# batch num: 146 wall time consumed: 40.04754066467285
# batch num: 147 wall time consumed: 40.29737043380737
# batch num: 148 wall time consumed: 40.00936245918274
# batch num: 149 wall time consumed: 40.22543430328369
# batch num: 150 wall time consumed: 40.57715725898743
# batch num: 151 wall time consumed: 40.40532445907593
# batch num: 152 wall time consumed: 40.52768087387085
# batch num: 153 wall time consumed: 40.542179346084595
# batch num: 154 wall time consumed: 40.189953565597534
# batch num: 155 wall time consumed: 40.17408108711243
# batch num: 156 wall time consumed: 40.75969696044922
# batch num: 157 wall time consumed: 40.14877724647522
# batch num: 158 wall time consumed: 40.312551975250244
# batch num: 159 wall time consumed: 40.66735124588013
# batch num: 160 wall time consumed: 40.54019069671631
# batch num: 161 wall time consumed: 40.53108024597168
# batch num: 162 wall time consumed: 40.16140103340149
# batch num: 163 wall time consumed: 40.48233103752136
# batch num: 164 wall time consumed: 40.542245388031006
# batch num: 165 wall time consumed: 40.16944766044617
# batch num: 166 wall time consumed: 40.40338850021362
# batch num: 167 wall time consumed: 40.166285037994385
# batch num: 168 wall time consumed: 40.79670548439026
# batch num: 169 wall time consumed: 40.4586455821991
# batch num: 170 wall time consumed: 40.408084869384766
# batch num: 171 wall time consumed: 40.82304406166077
# batch num: 172 wall time consumed: 40.483914375305176
# batch num: 173 wall time consumed: 40.746283769607544
# batch num: 174 wall time consumed: 40.2027850151062
# batch num: 175 wall time consumed: 40.48437786102295
# batch num: 176 wall time consumed: 40.18184542655945
# batch num: 177 wall time consumed: 39.86741781234741
# batch num: 178 wall time consumed: 40.39306616783142
# batch num: 179 wall time consumed: 40.12520432472229
# batch num: 180 wall time consumed: 40.34952139854431
# batch num: 181 wall time consumed: 40.64060306549072
# batch num: 182 wall time consumed: 40.059144735336304
# batch num: 183 wall time consumed: 40.520100593566895
# batch num: 184 wall time consumed: 40.20403861999512
# batch num: 185 wall time consumed: 40.55278491973877
# batch num: 186 wall time consumed: 40.32102870941162
# batch num: 187 wall time consumed: 40.7543683052063
# batch num: 188 wall time consumed: 40.319583892822266
# batch num: 189 wall time consumed: 40.153050661087036
# batch num: 190 wall time consumed: 40.22521352767944
# batch num: 191 wall time consumed: 40.48051691055298
# batch num: 192 wall time consumed: 40.271411418914795
# batch num: 193 wall time consumed: 40.63960576057434
# batch num: 194 wall time consumed: 40.50330901145935
# batch num: 195 wall time consumed: 40.54844331741333
# batch num: 196 wall time consumed: 40.065935134887695
# batch num: 197 wall time consumed: 40.23811721801758
# batch num: 198 wall time consumed: 40.188374757766724
# batch num: 199 wall time consumed: 40.24985146522522
# batch num: 200 wall time consumed: 40.56078290939331
# batch num: 201 wall time consumed: 40.55417013168335
# batch num: 202 wall time consumed: 40.40698480606079
# batch num: 203 wall time consumed: 40.349528312683105
# batch num: 204 wall time consumed: 40.34094476699829
# batch num: 205 wall time consumed: 40.44577121734619
# batch num: 206 wall time consumed: 40.42635488510132
# batch num: 207 wall time consumed: 40.21806740760803
# batch num: 208 wall time consumed: 40.1658239364624
# batch num: 209 wall time consumed: 40.55974555015564
# batch num: 210 wall time consumed: 40.50326585769653
# batch num: 211 wall time consumed: 39.909419775009155
# batch num: 212 wall time consumed: 40.48849034309387
# batch num: 213 wall time consumed: 40.341416358947754
# batch num: 214 wall time consumed: 40.088600635528564
# batch num: 215 wall time consumed: 40.182764530181885
# batch num: 216 wall time consumed: 40.0259644985199
# batch num: 217 wall time consumed: 40.34016132354736
# batch num: 218 wall time consumed: 40.70956754684448
# batch num: 219 wall time consumed: 40.66976857185364
# batch num: 220 wall time consumed: 40.505659103393555
# batch num: 221 wall time consumed: 40.15509271621704
# batch num: 222 wall time consumed: 40.32748317718506
# batch num: 223 wall time consumed: 40.260148763656616
# batch num: 224 wall time consumed: 40.78531503677368
# batch num: 225 wall time consumed: 40.30566477775574
# batch num: 226 wall time consumed: 39.99267077445984
# batch num: 227 wall time consumed: 40.77316403388977
# batch num: 228 wall time consumed: 40.17411279678345
# batch num: 229 wall time consumed: 40.19795489311218
# batch num: 230 wall time consumed: 40.514018058776855
# batch num: 231 wall time consumed: 40.52950072288513
# batch num: 232 wall time consumed: 40.630128145217896
# batch num: 233 wall time consumed: 40.25669264793396

# %%
len(images)
# Out:
# 2

# %%
len(action_records)
# Out:
# 4096

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
for ii,image in enumerate(images[:20]):
    plt.figure()
    plt.imshow(image)
    qq=np.array(q_records[ii]).transpose()
    plt.plot(32+qq[0],256-32-qq[1])
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">
# <img src="data:image/png;base64,..." width="639.4">

# %%
def freq(a):
    vals = sorted(set(a))
    freqs = {v:0 for v in vals}
    for q in a:
        freqs[q]+=1
    return np.array([freqs[q] for q in sorted(freqs.keys())])
def act_ent(a,epsilon=1e-20):
    f=freq(a)
    p=f/np.sum(f)
    return -np.sum(p*np.log2(p+epsilon))

# %%
ent_vec=[act_ent(aa) for aa in action_records]

# %%
plt.figure()
plt.hist(ent_vec)
# Out:
# (array([  51.,   84.,   87.,   90.,  117.,   94.,  109.,  138., 1458.,
#         1868.]),
#  array([0.11718782, 0.3827184 , 0.64824899, 0.91377957, 1.17931015,
#         1.44484073, 1.71037132, 1.9759019 , 2.24143248, 2.50696307,
#         2.77249365]),
#  <a list of 10 Patch objects>)

# %%
def prep_n_grams(x,n=None,offsets=None):
    if (n is None) and  not (offsets is None):
        pass
    elif not(n is None) and (offsets is None):
        offsets = list(range(n))
    else:
        error('need to provide either n or offsets')
    ngram_dict = {}
    for ii in range(len(x)-offsets[-1]):
        this_ngram = tuple(x[ii+oo] for oo in offsets)
        if this_ngram in ngram_dict.keys():
            ngram_dict[this_ngram] +=1
        else:
            ngram_dict[this_ngram] = 1
    return ngram_dict

# %%
ngrams=prep_n_grams(action_records[0],offsets=[0,3,6])

# %%
plt.hist([ii[-1] for ii in ngrams.items()],log=True,bins=20)
# Out:
# (array([101.,  24.,  11.,   4.,   2.,   5.,   0.,   1.,   2.,   0.,   0.,
#           0.,   1.,   2.,   1.,   0.,   0.,   1.,   0.,   1.]),
#  array([ 1. ,  4.3,  7.6, 10.9, 14.2, 17.5, 20.8, 24.1, 27.4, 30.7, 34. ,
#         37.3, 40.6, 43.9, 47.2, 50.5, 53.8, 57.1, 60.4, 63.7, 67. ]),
#  <a list of 20 Patch objects>)

# %%
action_records_all = []
for uu in action_records:
    action_records_all += uu

# %%
ngrams_all=prep_n_grams(action_records_all,offsets=[0,3,6])

# %%
plt.hist([ii[-1] for ii in ngrams_all.items()],log=True,bins=300)
plt.xlim([0,100000])
# Out:
# (0, 100000)

# %%
plt.semilogy(sorted([ii[-1] for ii in ngrams_all.items()],reverse=True))

# %%
mm=len(recorders)//40
for imag_num in range(mm):
#     plt.figure()
    for qq in range(40):
        if not qq%5:
            print('')
        recorder = recorders[mm*qq+imag_num]
        print("%2.2f   " % act_ent(recorder.records[-1]),end='')

    print('\n-----------------------------------------------------------')
# Out:
# 0.17   2.43   1.38   0.64   1.39
# 0.72   2.52   1.10   1.77   1.38
# 0.48   1.41   2.15   2.22   1.93
# 1.96   2.33   2.61   2.41   0.09
# 0.04   1.75   1.59   0.99   0.12
# 0.12   2.37   1.95   1.53   1.55
# 0.42   2.32   2.12   2.41   1.72
# 1.10   0.91   1.60   1.83   1.50
# -----------------------------------------------------------
#
# 0.02   1.63   1.51   1.57   1.56
# 0.61   0.69   1.01   0.98   1.35
# 1.30   2.20   2.20   2.28   2.24
# 1.93   2.70   2.46   2.32   1.86
# 0.03   1.79   1.02   0.92   0.47
# 0.03   1.72   0.30   1.11   0.60
# 1.44   2.14   1.57   2.63   1.52
# 0.30   0.22   1.58   1.80   0.81
# -----------------------------------------------------------
#
# 0.02   1.87   0.81   1.18   1.01
# 0.46   1.28   2.37   1.41   0.95
# 0.68   1.58   2.23   2.03   2.21
# 0.15   2.76   2.50   2.43   1.50
# -0.00   1.43   0.28   0.90   0.44
# 0.08   2.32   0.70   0.93   1.36
# 2.40   2.32   1.80   1.61   1.75
# 1.41   2.21   2.09   1.52   1.49
# -----------------------------------------------------------
#
# 0.02   1.46   1.20   0.64   1.40
# 0.41   0.38   1.43   1.43   0.78
# 0.29   0.24   2.09   2.11   1.72
# 1.89   2.33   2.35   2.06   1.90
# 0.01   1.16   0.75   0.71   0.43
# 0.06   2.11   1.48   0.97   1.01
# 0.69   2.06   1.56   2.51   1.58
# 0.17   1.40   1.94   1.57   1.11
# -----------------------------------------------------------
#
# 0.02   1.39   1.27   0.49   1.57
# 0.45   0.40   0.84   1.14   0.91
# 0.69   2.51   2.24   2.00   2.15
# 0.15   2.29   2.20   2.48   0.47
# 0.01   1.70   1.25   1.02   1.09
# -0.00   1.61   1.24   0.98   1.00
# 0.61   2.26   0.79   2.56   1.55
# 0.51   2.07   2.05   1.46   0.79
# -----------------------------------------------------------
#
# 0.34   1.05   0.83   0.45   0.99
# 0.53   1.51   1.78   1.91   0.95
# 0.75   0.68   1.99   2.34   2.27
# 0.17   2.35   2.63   2.44   0.11
# 0.01   1.08   1.05   1.02   0.13
# 0.15   0.64   1.43   1.40   1.41
# 0.73   2.42   2.26   2.44   1.66
# 0.62   1.21   2.14   0.62   1.29
# -----------------------------------------------------------
#
# 0.14   1.97   1.63   1.31   1.56
# 0.39   1.12   2.15   1.18   1.87
# 0.32   0.69   0.56   2.46   2.59
# 0.29   0.43   1.50   2.46   2.12
# 0.02   1.67   0.73   1.42   0.76
# 0.07   2.52   1.20   0.87   1.58
# 0.34   0.30   1.77   0.57   1.70
# 0.67   0.22   2.27   0.18   1.55
# -----------------------------------------------------------
#
# 0.05   2.55   1.55   1.46   1.66
# 0.51   0.98   2.02   1.90   1.15
# 0.67   1.28   2.21   2.44   2.41
# 2.00   2.49   2.48   2.35   1.74
# 0.01   1.93   1.54   0.94   1.00
# 0.06   1.88   0.76   1.56   1.27
# 0.32   2.12   2.29   2.58   1.28
# 0.50   0.97   2.02   0.73   1.34
# -----------------------------------------------------------
#
# 0.04   1.96   1.32   0.87   1.06
# 0.31   0.68   0.54   1.19   0.66
# 0.39   1.19   2.35   1.65   2.56
# 0.19   0.39   2.40   2.46   1.31
# 0.02   0.90   0.70   0.65   0.40
# 0.07   2.36   1.05   0.55   0.59
# 0.49   2.19   1.69   1.17   1.84
# 0.37   1.00   2.20   1.83   1.45
# -----------------------------------------------------------
#
# 0.09   1.29   1.55   0.97   1.35
# 0.62   0.76   1.52   1.02   0.63
# 0.92   0.55   2.11   2.27   2.38
# 1.88   2.62   2.40   2.34   0.31
# 0.02   1.22   1.55   0.87   0.53
# 0.12   2.14   1.00   0.61   1.05
# 0.38   2.13   1.87   2.55   1.74
# 0.57   0.20   1.80   1.75   0.92
# -----------------------------------------------------------
#
# 0.05   1.52   1.02   1.61   1.89
# 0.67   1.32   1.72   0.51   1.40
# 0.36   0.80   0.95   0.95   2.54
# 1.52   0.84   2.30   1.55   1.05
# 0.02   2.36   0.65   0.66   1.00
# 0.09   1.67   1.13   1.69   1.24
# 0.40   1.39   1.62   2.46   1.78
# 0.52   0.27   0.90   2.02   1.25
# -----------------------------------------------------------
#
# 0.42   0.95   1.08   0.53   1.76
# 0.43   0.77   1.16   1.35   1.00
# 0.33   0.36   1.48   1.78   2.20
# 1.93   2.30   2.23   2.30   0.83
# 0.02   1.21   0.85   0.55   0.47
# 0.14   2.57   1.15   1.35   0.73
# 1.49   0.49   1.58   2.51   1.32
# 0.39   0.41   2.11   1.54   0.97
# -----------------------------------------------------------
#
# 0.14   2.31   1.80   1.77   1.30
# 1.05   0.69   2.08   0.76   0.64
# 2.20   2.41   2.42   2.39   2.51
# 0.12   2.85   2.49   2.35   1.97
# 0.01   1.38   0.82   0.66   1.00
# 0.03   2.47   1.45   1.17   1.37
# 2.49   2.35   2.23   2.51   2.24
# 0.67   2.15   2.16   1.74   1.25
# -----------------------------------------------------------
#
# 0.02   0.49   1.58   0.43   1.29
# 0.58   1.43   1.12   1.12   0.62
# 0.50   0.31   2.03   2.12   2.19
# 0.69   2.42   2.50   2.15   1.76
# -0.00   1.76   1.02   0.96   1.58
# 0.09   2.57   1.46   0.96   1.54
# 0.75   1.72   1.97   2.41   0.56
# 0.88   0.73   1.28   1.08   1.13
# -----------------------------------------------------------
#
# 0.03   2.30   1.01   0.77   0.94
# 0.56   0.61   0.55   1.22   0.67
# 0.40   1.32   2.38   2.46   2.64
# 0.26   0.29   2.24   2.50   0.65
# 0.04   1.54   0.75   0.82   0.41
# 0.07   2.40   1.02   0.95   0.87
# 0.45   2.42   1.50   1.64   1.99
# 0.21   0.48   2.07   1.76   1.28
# -----------------------------------------------------------
#
# 0.02   0.99   1.40   2.25   1.76
# 0.48   0.83   0.42   1.36   1.11
# 0.33   0.24   2.20   2.12   1.91
# 0.70   2.23   2.55   2.34   1.75
# 0.03   1.54   0.96   1.30   1.03
# -0.00   1.35   1.86   1.32   0.82
# 0.55   1.62   1.97   2.29   1.27
# 0.24   1.31   1.86   1.49   1.11
# -----------------------------------------------------------
#
# 0.06   0.60   1.58   1.74   0.82
# 1.02   2.25   1.60   1.68   1.39
# 1.06   0.17   0.91   2.17   2.17
# 1.94   2.36   2.63   2.45   0.63
# 0.01   2.10   0.70   0.88   1.35
# 0.07   2.04   0.70   1.17   0.72
# 0.21   2.08   1.56   2.56   1.51
# 0.32   1.21   2.23   1.58   1.11
# -----------------------------------------------------------
#
# 0.02   2.27   0.97   1.05   1.80
# 0.46   1.66   1.63   2.07   0.97
# 0.71   2.14   2.08   1.96   2.25
# 2.00   2.66   2.50   2.29   0.24
# 0.03   1.96   1.03   2.21   1.24
# 0.01   2.52   1.52   1.69   1.00
# 0.71   2.17   2.03   2.60   1.92
# 0.23   0.11   2.02   1.79   1.51
# -----------------------------------------------------------
#
# 0.05   1.67   0.50   1.08   0.59
# 0.57   1.08   1.61   1.62   0.64
# 0.31   1.01   2.26   2.04   0.83
# 0.24   0.19   0.46   0.95   1.59
# -0.00   1.96   0.49   0.95   0.56
# 0.04   2.08   0.80   0.95   1.70
# 0.89   0.80   1.83   2.15   1.09
# 0.71   0.37   1.12   1.49   1.19
# -----------------------------------------------------------
#
# 0.02   1.64   1.29   0.58   0.80
# 0.53   1.41   1.44   1.83   0.84
# 0.31   1.01   2.11   1.93   2.29
# 0.38   2.55   2.57   2.33   0.54
# 0.01   1.09   1.03   1.19   0.35
# 0.02   2.39   1.18   1.20   1.50
# 0.30   0.51   1.61   2.52   0.89
# 0.23   0.34   2.17   1.78   1.32
# -----------------------------------------------------------

# %%
mm=len(recorders)//40
ent_rec=np.zeros([mm,40])
for imag_num in range(mm):
#     plt.figure()
    for qq in range(40):
        recorder = recorders[mm*qq+imag_num]
        ent_rec[imag_num,qq]= act_ent(recorder.records[-1])

#     print('\n-----------------------------------------------------------')

# %%
mm
# Out:
# 20

# %%
np.mean(ent_rec,axis=0).reshape([8,5])
# Out:
# array([[0.08867333, 1.61768941, 1.26392938, 1.06934454, 1.32479101],
#        [0.56778131, 1.118531  , 1.40481863, 1.37234476, 0.99483986],
#        [0.65041922, 1.10456292, 1.94771928, 2.08575282, 2.19934374],
#        [1.01889872, 1.96847589, 2.30019204, 2.24871808, 1.12087346],
#        [0.01799131, 1.57575043, 0.93726747, 0.97995684, 0.71790542],
#        [0.06684287, 2.08576268, 1.1694828 , 1.14776738, 1.14449013],
#        [0.80236751, 1.79133908, 1.78195371, 2.2334211 , 1.54591131],
#        [0.53086538, 0.88911144, 1.88077619, 1.47832672, 1.21894077]])

# %%
np.std(ent_rec,axis=0).reshape([8,5])
# Out:
# array([[0.1075296 , 0.58613794, 0.32399309, 0.51226776, 0.36940398],
#        [0.18299763, 0.55572623, 0.54100699, 0.3993687 , 0.3329549 ],
#        [0.4479287 , 0.73012142, 0.51751262, 0.33841748, 0.38995168],
#        [0.80926828, 0.91072015, 0.4862404 , 0.36071324, 0.6806439 ],
#        [0.01196951, 0.37923138, 0.33740237, 0.35205962, 0.40461655],
#        [0.04216233, 0.48016429, 0.39385541, 0.31457041, 0.34203969],
#        [0.63991391, 0.68518811, 0.3361976 , 0.54030882, 0.38239973],
#        [0.31184571, 0.66062811, 0.37916077, 0.45935426, 0.22073964]])

# %%
plt.figure()
plt.imshow(np.mean(ent_rec,axis=0).reshape([8,5]))
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="639.4">

# %%
labels[:20]
# Out:
# array('B', [5, 0, 4, 1, 9, 2, 1, 3, 1, 4, 3, 5, 3, 6, 1, 7, 2, 8, 6, 9])

# %%
labels[1]
# Out:
# 0

# %%
len(labels)
# Out:
# 60000

# %%
mm=len(recorders)//40
diff_rec=np.zeros([mm,40])
for imag_num in range(mm):
#     plt.figure()
    for qq in range(40):
        recorder = np.array(recorders[mm*qq+imag_num].records[-1])
        diff_rec[imag_num,qq]=np.mean(recorder[:-1]!=recorder[1:])

# %%
np.mean(diff_rec,axis=0).reshape([-1,5])
# Out:
# array([[0.01046046, 0.24654655, 0.23423423, 0.19164164, 0.19389389],
#        [0.01781782, 0.10915916, 0.23413413, 0.21386386, 0.17472472],
#        [0.06991992, 0.1525025 , 0.33808809, 0.36466466, 0.3998999 ],
#        [0.19129129, 0.25335335, 0.32537538, 0.35385385, 0.1538038 ],
#        [0.00225225, 0.30955956, 0.22992993, 0.21866867, 0.21846847],
#        [0.0048048 , 0.36246246, 0.18133133, 0.25475475, 0.3548048 ],
#        [0.07517518, 0.25855856, 0.26111111, 0.34474474, 0.26156156],
#        [0.04344344, 0.09404404, 0.26976977, 0.20825826, 0.23878879]])

# %%
plt.figure()
plt.subplot(1,2,1)
plt.imshow(np.mean(ent_rec,axis=0).reshape([8,5]))
plt.colorbar()
plt.title('action entropy')
plt.ylabel('speed penalty/fading setting')
plt.xlabel('gamma setting')
plt.subplot(1,2,2)
plt.imshow(np.mean(diff_rec,axis=0).reshape([-1,5]))
plt.colorbar()
plt.title('action switching rate')
plt.xlabel('gamma setting')
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# Text(0.5, 0, 'gamma setting')

# %%
len(action_records)
# Out:
# 4096

# %%
len(labels)
# Out:
# 60000

# %% [markdown]
# with open('mnist_boltz1_act_full1.pkl','wb') as f:
#     pickle.dump([action_records[:30000],labels[:30000]],f)
#
# with open('mnist_boltz1_act_full2.pkl','wb') as f:
#     pickle.dump([action_records[30000:],labels[30000:]],f)

# %%
labels[:len(action_records)]
# Out:
# array('B', [5, 0, 4, 1, 9, 2, 1, 3, 1, 4, 3, 5, 3, 6, 1, 7, 2, 8, 6, 9, 4, 0, 9, 1, 1, 2, 4, 3, 2, 7, 3, 8, 6, 9, 0, 5, 6, 0, 7, 6, 1, 8, 7, 9, 3, 9, 8, 5, 9, 3, 3, 0, 7, 4, 9, 8, 0, 9, 4, 1, 4, 4, 6, 0, 4, 5, 6, 1, 0, 0, 1, 7, 1, 6, 3, 0, 2, 1, 1, 7, 9, 0, 2, 6, 7, 8, 3, 9, 0, 4, 6, 7, 4, 6, 8, 0, 7, 8, 3, 1, 5, 7, 1, 7, 1, 1, 6, 3, 0, 2, 9, 3, 1, 1, 0, 4, 9, 2, 0, 0, 2, 0, 2, 7, 1, 8, 6, 4, 1, 6, 3, 4, 5, 9, 1, 3, 3, 8, 5, 4, 7, 7, 4, 2, 8, 5, 8, 6, 7, 3, 4, 6, 1, 9, 9, 6, 0, 3, 7, 2, 8, 2, 9, 4, 4, 6, 4, 9, 7, 0, 9, 2, 9, 5, 1, 5, 9, 1, 2, 3, 2, 3, 5, 9, 1, 7, 6, 2, 8, 2, 2, 5, 0, 7, 4, 9, 7, 8, 3, 2, 1, 1, 8, 3, 6, 1, 0, 3, 1, 0, 0, 1, 7, 2, 7, 3, 0, 4, 6, 5, 2, 6, 4, 7, 1, 8, 9, 9, 3, 0, 7, 1, 0, 2, 0, 3, 5, 4, 6, 5, 8, 6, 3, 7, 5, 8, 0, 9, 1, 0, 3, 1, 2, 2, 3, 3, 6, 4, 7, 5, 0, 6, 2, 7, 9, 8, 5, 9, 2, 1, 1, 4, 4, 5, 6, 4, 1, 2, 5, 3, 9, 3, 9, 0, 5, 9, 6, 5, 7, 4, 1, 3, 4, 0, 4, 8, 0, 4, 3, 6, 8, 7, 6, 0, 9, 7, 5, 7, 2, 1, 1, 6, 8, 9, 4, 1, 5, 2, 2, 9, 0, 3, 9, 6, 7, 2, 0, 3, 5, 4, 3, 6, 5, 8, 9, 5, 4, 7, 4, 2, 7, 3, 4, 8, 9, 1, 9, 2, 8, 7, 9, 1, 8, 7, 4, 1, 3, 1, 1, 0, 2, 3, 9, 4, 9, 2, 1, 6, 8, 4, 7, 7, 4, 4, 9, 2, 5, 7, 2, 4, 4, 2, 1, 9, 7, 2, 8, 7, 6, 9, 2, 2, 3, 8, 1, 6, 5, 1, 1, 0, 2, 6, 4, 5, 8, 3, 1, 5, 1, 9, 2, 7, 4, 4, 4, 8, 1, 5, 8, 9, 5, 6, 7, 9, 9, 3, 7, 0, 9, 0, 6, 6, 2, 3, 9, 0, 7, 5, 4, 8, 0, 9, 4, 1, 2, 8, 7, 1, 2, 6, 1, 0, 3, 0, 1, 1, 8, 2, 0, 3, 9, 4, 0, 5, 0, 6, 1, 7, 7, 8, 1, 9, 2, 0, 5, 1, 2, 2, 7, 3, 5, 4, 9, 7, 1, 8, 3, 9, 6, 0, 3, 1, 1, 2, 6, 3, 5, 7, 6, 8, 3, 9, 5, 8, 5, 7, 6, 1, 1, 3, 1, 7, 5, 5, 5, 2, 5, 8, 7, 0, 9, 7, 7, 5, 0, 9, 0, 0, 8, 9, 2, 4, 8, 1, 6, 1, 6, 5, 1, 8, 3, 4, 0, 5, 5, 8, 3, 6, 2, 3, 9, 2, 1, 1, 5, 2, 1, 3, 2, 8, 7, 3, 7, 2, 4, 6, 9, 7, 2, 4, 2, 8, 1, 1, 3, 8, 4, 0, 6, 5, 9, 3, 0, 9, 2, 4, 7, 1, 2, 9, 4, 2, 6, 1, 8, 9, 0, 6, 6, 7, 9, 9, 8, 0, 1, 4, 4, 6, 7, 1, 5, 7, 0, 3, 5, 8, 4, 7, 1, 2, 5, 9, 5, 6, 7, 5, 9, 8, 8, 3, 6, 9, 7, 0, 7, 5, 7, 1, 1, 0, 7, 9, 2, 3, 7, 3, 2, 4, 1, 6, 2, 7, 5, 5, 7, 4, 0, 2, 6, 3, 6, 4, 0, 4, 2, 6, 0, 0, 0, 0, 3, 1, 6, 2, 2, 3, 1, 4, 1, 5, 4, 6, 4, 7, 2, 8, 7, 9, 2, 0, 5, 1, 4, 2, 8, 3, 2, 4, 1, 5, 4, 6, 0, 7, 9, 8, 4, 9, 8, 0, 1, 1, 0, 2, 2, 3, 2, 4, 4, 5, 8, 6, 5, 7, 7, 8, 8, 9, 7, 4, 7, 3, 2, 0, 8, 6, 8, 6, 1, 6, 8, 9, 4, 0, 9, 0, 4, 1, 5, 4, 7, 5, 3, 7, 4, 9, 8, 5, 8, 6, 3, 8, 6, 9, 9, 1, 8, 3, 5, 8, 6, 5, 9, 7, 2, 5, 0, 8, 5, 1, 1, 0, 9, 1, 8, 6, 7, 0, 9, 3, 0, 8, 8, 9, 6, 7, 8, 4, 7, 5, 9, 2, 6, 7, 4, 5, 9, 2, 3, 1, 6, 3, 9, 2, 2, 5, 6, 8, 0, 7, 7, 1, 9, 8, 7, 0, 9, 9, 4, 6, 2, 8, 5, 1, 4, 1, 5, 5, 1, 7, 3, 6, 4, 3, 2, 5, 6, 4, 4, 0, 4, 4, 6, 7, 2, 4, 3, 3, 8, 0, 0, 3, 2, 2, 9, 8, 2, 3, 7, 0, 1, 1, 0, 2, 3, 3, 8, 4, 3, 5, 7, 6, 4, 7, 7, 8, 5, 9, 7, 0, 3, 1, 6, 2, 4, 3, 4, 4, 7, 5, 9, 6, 9, 0, 7, 1, 4, 2, 7, 3, 6, 7, 5, 8, 4, 5, 5, 2, 7, 1, 1, 5, 6, 8, 5, 8, 4, 0, 7, 9, 9, 2, 9, 7, 7, 8, 7, 4, 2, 6, 9, 1, 7, 0, 6, 4, 2, 5, 7, 0, 7, 1, 0, 3, 7, 6, 5, 0, 6, 1, 5, 1, 7, 8, 5, 0, 3, 4, 7, 7, 5, 7, 8, 6, 9, 3, 8, 6, 1, 0, 9, 7, 1, 3, 0, 5, 6, 4, 4, 2, 4, 4, 3, 1, 7, 7, 6, 0, 3, 6, 0, 7, 1, 1, 4, 9, 4, 3, 4, 8, 2, 2, 1, 8, 7, 0, 8, 1, 0, 7, 6, 3, 7, 7, 5, 8, 8, 9, 0, 0, 4, 1, 5, 2, 2, 3, 9, 4, 9, 5, 0, 6, 7, 7, 1, 8, 0, 2, 2, 0, 4, 1, 1, 2, 7, 3, 9, 7, 2, 8, 1, 9, 5, 8, 8, 1, 9, 8, 3, 1, 6, 5, 7, 4, 2, 7, 0, 3, 0, 4, 1, 1, 7, 9, 1, 1, 8, 5, 7, 5, 0, 6, 6, 0, 4, 1, 2, 3, 4, 4, 6, 8, 0, 9, 5, 8, 7, 0, 3, 5, 4, 5, 9, 6, 7, 1, 9, 6, 1, 3, 8, 3, 9, 1, 2, 7, 7, 7, 0, 2, 3, 1, 1, 4, 2, 5, 6, 0, 9, 6, 2, 8, 9, 2, 3, 3, 6, 9, 1, 4, 3, 3, 0, 7, 7, 1, 7, 7, 3, 6, 4, 9, 5, 4, 4, 2, 7, 9, 0, 9, 8, 4, 4, 9, 1, 2, 4, 9, 3, 0, 4, 1, 6, 2, 6, 3, 7, 4, 2, 6, 6, 7, 1, 8, 9, 0, 4, 1, 4, 2, 1, 3, 6, 4, 6, 7, 5, 8, 7, 0, 5, 1, 4, 2, 8, 4, 7, 7, 3, 8, 4, 9, 5, 8, 6, 7, 3, 4, 6, 7, 1, 7, 4, 3, 3, 9, 8, 8, 1, 8, 6, 3, 1, 1, 3, 5, 2, 8, 4, 2, 9, 7, 1, 4, 8, 2, 9, 6, 4, 1, 3, 4, 2, 5, 2, 5, 6, 8, 0, 6, 2, 4, 9, 4, 9, 4, 5, 1, 5, 8, 4, 7, 9, 5, 9, 5, 9, 1, 5, 8, 3, 9, 9, 1, 8, 3, 8, 6, 5, 2, 7, 2, 7, 6, 0, 9, 7, 9, 4, 6, 0, 5, 3, 5, 7, 3, 9, 3, 6, 8, 3, 1, 7, 6, 5, 5, 7, 6, 5, 8 ...

# %%
1+1+1
# Out:
# 3
