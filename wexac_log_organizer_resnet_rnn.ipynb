# %%
import pickle
import re
import numpy as np
import ast

# %%
from os import listdir
import glob

# %%
file_names = glob.glob('../../iclr_result_dirs/keras-resnet//out*')

# %%
len(file_names)
# Out:
# 151

# %%
file_name='../../iclr_result_dirs/teacher_student/out_traject.831800'

# %%
def vanilla_out_parser(file_name):    
    count_test_results = 0
    done_config = False
    accu_list=[]
    with open(file_name,'r') as f:
        for line in f:
            if not done_config and line[:6]=='config':
                config_dict_str = line[7:].lstrip()
                done_config = True
            if line[:6] == 'python':
                python_commant = line
            if count_test_results > 0:
                accu = line.split(':')[-1]
                accu_list.append(float(accu))
                count_test_results -= 1
            if 'now testing:' in line:
                count_test_results = 5

    # print(accu_list)
    if len(accu_list)>0:
        config_dict = ast.literal_eval(config_dict_str)
#         print(config_dict)
#         print(np.mean(accu_list))
        config_dict['accuracy'] = np.mean(accu_list)
        config_dict['accuracy_std'] = np.std(accu_list)
#         config_dict['accuracy'] = np.mean(accu_list)
        return config_dict
    else:
        return None

# %%
records = []
for ii,file_name in enumerate(file_names):
    conf=vanilla_out_parser(file_name)
    if conf is not None:
        conf['file_name']=file_name.split('/')[-1]
        conf['file_name_full']=file_name
#         conf['teacher_short']=conf['teacher_net'][-25:]
#         print(conf['teacher_short'])
        records.append(conf)

# %%
import pandas as pd

# %%
df = pd.DataFrame(records)

# %%
df
# Out:
#     accuracy  accuracy_std add_trajectory  broadcast  conv_back_end  \
# 0    0.73864  2.100095e-03              0          0           True
# 1    0.82838  2.007386e-03              0          0           True
# 2    0.83746  1.821648e-03              0          0           True
# 3    0.80888  2.512688e-03              0          0           True
# 4    0.83788  1.208967e-03              0          0           True
# 5    0.57990  0.000000e+00              0          0           True
# 6    0.82760  0.000000e+00              0          0           True
# 7    0.69442  1.220492e-03              0          0           True
# 8    0.57890  0.000000e+00              0          0           True
# 9    0.83260  1.231260e-03              0          0           True
# 10   0.83070  0.000000e+00              0          0           True
# 11   0.84058  1.270276e-03              1          0           True
# 12   0.58566  1.852134e-03              0          0           True
# 13   0.83178  1.885099e-03              0          0           True
# 14   0.58468  2.144201e-03              0          0           True
# 15   0.07890  0.000000e+00              0          0           True
# 16   0.83844  1.739655e-03              0          0           True
# 17   0.58852  1.984339e-03              0          0           True
# 18   0.83664  1.281562e-03              1          0           True
# 19   0.80598  1.210620e-03              0          0           True
# 20   0.82680  1.110223e-16              0          0           True
# 21   0.83606  1.918958e-03              0          0           True
# 22   0.57670  0.000000e+00              0          0           True
#
#    conv_rnn_type  early_stopper_option  epochs        file_name  \
# 0            gru                   0.0     100  out2_net.988930
# 1            gru                   2.0     100  out2_net.988893
# 2            gru                   0.0     100  out2_net.989179
# 3            gru                   1.0     100  out2_net.988892
# 4            gru                   2.0     100  out2_net.988971
# 5            gru                   NaN     100  out2_net.926421
# 6            gru                   NaN     100  out2_net.926418
# 7            gru                   0.0     100  out2_net.988891
# 8            gru                   NaN     100  out2_net.926419
# 9            gru                   0.0     100  out2_net.984439
# 10           gru                   NaN     100  out2_net.927236
# 11           gru                   0.0     100  out2_net.989385
# 12           gru                   0.0     100  out2_net.989183
# 13           gru                   0.0     100  out2_net.985087
# 14           gru                   0.0     100  out2_net.989184
# 15           gru                   NaN       0  out2_net.926422
# 16           gru                   0.0     100  out2_net.989181
# 17           gru                   0.0     100  out2_net.989185
# 18           gru                   0.0     100  out2_net.989382
# 19           gru                   1.0     100  out2_net.988965
# 20           gru                   NaN     100  out2_net.927238
# 21           gru                   0.0     100  out2_net.988895
# 22           gru                   NaN     100  out2_net.926420
#
#                                        file_name_full      ...       noise  \
# 0   ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 1   ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 2   ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 3   ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 4   ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 5   ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 6   ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 7   ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 8   ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 9   ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 10  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 11  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 12  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 13  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 14  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 15  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 16  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 17  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 18  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 19  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 20  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
# 21  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.50
# 22  ../../iclr_result_dirs/keras-resnet/out2_net.9...      ...        0.15
#
#     optimizer  position_scale  preload_weights  res  stopping_patience  \
# 0        Adam             NaN         imagenet    8                 10
# 1         NaN             NaN         imagenet    8                 10
# 2         SGD             NaN         imagenet    8                 10
# 3         NaN             NaN         imagenet    8                 10
# 4         SGD             NaN         imagenet    8                 10
# 5         NaN             NaN              NaN    8                 10
# 6         NaN             NaN              NaN    8                 10
# 7         NaN             NaN             None    8                 10
# 8         NaN             NaN              NaN    8                 10
# 9         NaN             NaN             None    8                 10
# 10        NaN             NaN              NaN    8                 10
# 11        SGD            10.0         imagenet    8                 10
# 12        SGD             NaN         imagenet    8                 10
# 13        NaN             NaN     banana_check    8                 10
# 14        SGD             NaN         imagenet    8                 10
# 15        NaN             NaN              NaN    8                 10
# 16        SGD             NaN         imagenet    8                 10
# 17        SGD             NaN         imagenet    8                 10
# 18        SGD             1.0         imagenet    8                 10
# 19        SGD             NaN         imagenet    8                 10
# 20        NaN             NaN              NaN    8                 10
# 21        NaN             NaN         imagenet    8                 10
# 22        NaN             NaN              NaN    8                 10
#
#            style  trainable trajectories_num  val_set_mult
# 0   spiral_2dir2       True               -1             5
# 1       brownian       True               -1             5
# 2   spiral_2dir2       True               -1             5
# 3       brownian       True               -1             5
# 4   spiral_2dir2       True               -1             5
# 5       brownian       True               -1             5
# 6       brownian       True               -1             5
# 7       brownian       True               -1             5
# 8       brownian       True               -1             5
# 9       brownian       True               -1             5
# 10      brownian       True               -1             5
# 11  spiral_2dir2       True               -1             5
# 12  spiral_2dir2       True               -1             5
# 13      brownian       True               -1             5
# 14  spiral_2dir2       True               -1             5
# 15      brownian       True               -1             5
# 16  spiral_2dir2       True               -1             5
# 17  spiral_2dir2       True               -1             5
# 18  spiral_2dir2       True               -1             5
# 19  spiral_2dir2       True               -1             5
# 20      brownian       True               -1             5
# 21  spiral_2dir2       True               -1             5
# 22      brownian       True               -1             5
#
# [23 rows x 27 columns]

# %%
df.columns
# Out:
# Index([], dtype='object')

# %%
df.sort_values(by=['n_classes']).loc[df['style']=='spiral_2dir2'].loc[:,['file_name',
                                                                         'style',
                                                                         'n_classes',
                                                                         'optimizer',
                                                                         'preload_weights', 
                                                                         'add_trajectory', 
                                                                         'position_scale',
                                                                         'epochs',
                                                                         'accuracy']]
# Out:
#           file_name         style  n_classes optimizer preload_weights  \
# 0   out2_net.988930  spiral_2dir2         10      Adam        imagenet
# 19  out2_net.988965  spiral_2dir2         10       SGD        imagenet
# 18  out2_net.989382  spiral_2dir2         10       SGD        imagenet
# 16  out2_net.989181  spiral_2dir2         10       SGD        imagenet
# 21  out2_net.988895  spiral_2dir2         10       NaN        imagenet
# 11  out2_net.989385  spiral_2dir2         10       SGD        imagenet
# 4   out2_net.988971  spiral_2dir2         10       SGD        imagenet
# 2   out2_net.989179  spiral_2dir2         10       SGD        imagenet
# 12  out2_net.989183  spiral_2dir2        100       SGD        imagenet
# 14  out2_net.989184  spiral_2dir2        100       SGD        imagenet
# 17  out2_net.989185  spiral_2dir2        100       SGD        imagenet
#
#    add_trajectory  position_scale  epochs  accuracy
# 0               0             NaN     100   0.73864
# 19              0             NaN     100   0.80598
# 18              1             1.0     100   0.83664
# 16              0             NaN     100   0.83844
# 21              0             NaN     100   0.83606
# 11              1            10.0     100   0.84058
# 4               0             NaN     100   0.83788
# 2               0             NaN     100   0.83746
# 12              0             NaN     100   0.58566
# 14              0             NaN     100   0.58468
# 17              0             NaN     100   0.58852
